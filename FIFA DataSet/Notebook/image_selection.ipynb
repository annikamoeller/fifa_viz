# %%
# !pip3 install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
from IPython.display import Image
import os 
import random
from unidecode import unidecode
import pandas as pd

# %%
def find_player(name):
    main_path = '../Data/FIFA World Cup 2022 Player Images/Images/'
    for group in os.listdir(main_path):
        if group != '.DS_Store':
            group_path = os.path.join(main_path, group)
            for team in os.listdir(group_path):
                if team != '.DS_Store':
                    team_path = os.path.join(group_path, team)
                    for player_folder in os.listdir(team_path):
                        if player_folder != '.DS_Store':
                            player_folder_no_Images_ = player_folder.split('_')[1] # remove 'Images_
                            player_folder_no_Images_or_captain = player_folder_no_Images_.split('(')[0].strip() # remove (captain)
                            player_folder_no_Images_captain_or_accents = unidecode(player_folder_no_Images_or_captain) # remove accents for comparison
                            name_processed = unidecode(name) # remove accents for comparison
                            # print(player_name_processed)
                            player_name_path = os.path.join(team_path, player_folder)
                            n_images = len(os.listdir(player_name_path))
                            random_number = random.randint(1,n_images)
                            if player_folder_no_Images_captain_or_accents == name_processed:
                                img_path = os.path.join(player_name_path, f'{player_folder_no_Images_}{random_number}.jpg')
                                # print(img_path)
                                return Image(filename=img_path)

# %%
names = pd.read_csv('../Data/FIFA World Cup 2022 Player Images/List Of All Players Names.csv', delimiter=',')

# %%
names_list = list(names['Name_Player'])
names_list
# Out:
# ['Hernán Galíndez',
#  'Félix Torres',
#  'Piero Hincapié',
#  'Robert Arboleda',
#  'José Cifuentes',
#  'William Pacho',
#  'Pervis Estupiñán',
#  'Carlos Gruezo',
#  'Ayrton Preciado',
#  'Romario Ibarra',
#  'Michael Estrada',
#  'Moisés Ramírez',
#  'Enner Valencia (captain)',
#  'Xavier Arreaga',
#  'Ángel Mena',
#  'Jeremy Sarmiento',
#  'Ángelo Preciado',
#  'Diego Palacios',
#  'Gonzalo Plata',
#  'Sebas Méndez',
#  'Alan Franco',
#  'Alexander Domínguez',
#  'Moisés Caicedo',
#  'Djorkaeff Reasco',
#  'Jackson Porozo',
#  'Kevin Rodríguez',
#  'Remko Pasveer',
#  'Jurriën Timber',
#  'Matthijs de Ligt',
#  'Virgil van Dijk (captain)',
#  'Nathan Aké',
#  'Stefan de Vrij',
#  'Steven Bergwijn',
#  'Cody Gakpo',
#  'Luuk de Jong',
#  'Memphis Depay',
#  'Steven Berghuis',
#  'Noa Lang',
#  'Justin Bijlow',
#  'Davy Klaassen',
#  'Marten de Roon',
#  'Tyrell Malacia',
#  'Daley Blind',
#  'Vincent Janssen',
#  'Wout Weghorst',
#  'Teun Koopmeiners',
#  'Frenkie de Jong',
#  'Denzel Dumfries',
#  'Andries Noppert',
#  'Kenneth Taylor',
#  'Xavi Simons',
#  'Jeremie Frimpong',
#  'Saad Al-Sheeb',
#  'Ró-Ró',
#  'Abdelkarim Hassan',
#  'Mohammed Waad',
#  'Tarek Salman',
#  'Abdulaziz Hatem',
#  'Ahmed Alaaeldin',
#  'Ali Assadalla',
#  'Mohammed Muntari',
#  'Hassan Al-Haydos (captain)',
#  'Akram Afif',
#  'Karim Boudiaf',
#  'Musab Kheder',
#  'Homam Ahmed',
#  'Bassam Al-Rawi',
#  'Boualem Khoukhi',
#  'Ismaeel Mohammad',
#  'Khalid Muneer',
#  'Almoez Ali',
#  'Salem Al-Hajri',
#  'Yousef Hassan',
#  'Meshaal Barsham',
#  'Assim Madibo',
#  'Naif Al-Hadhrami',
#  'Jassem Gaber',
#  'Mostafa Meshaal',
#  'Seny Dieng',
#  'Formose Mendy',
#  'Kalidou Koulibaly (captain)',
#  'Pape Abou Cissé',
#  'Idrissa Gueye',
#  'Nampalys Mendy',
#  'Nicolas Jackson',
#  'Cheikhou Kouyaté',
#  'Boulaye Dia',
#  "Moussa N'Diaye",
#  'Pathé Ciss',
#  'Fodé Ballo-Touré',
#  'Iliman Ndiaye',
#  'Ismail Jakobs',
#  'Krépin Diatta',
#  'Édouard Mendy',
#  'Pape Matar Sarr',
#  'Ismaïla Sarr',
#  'Famara Diédhiou',
#  'Bamba Dieng',
#  'Youssouf Sabaly',
#  'Abdou Diallo',
#  'Alfred Gomis',
#  'Moustapha Name',
#  'Mamadou Loum',
#  'Pape Gueye',
#  'Jordan Pickford',
#  'Kyle Walker',
#  'Luke Shaw',
#  'Declan Rice',
#  'John Stones',
#  'Harry Maguire',
#  'Jack Grealish',
#  'Jordan Henderson',
#  'Harry Kane (captain)',
#  'Raheem Sterling',
#  'Marcus Rashford',
#  'Kieran Trippier',
#  'Nick Pope',
#  'Kalvin Phillips',
#  'Eric Dier',
#  'Conor Coady',
#  'Bukayo Saka',
#  'Trent Alexander-Arnold',
#  'Mason Mount',
#  'Phil Foden',
#  'Ben White',
#  'Jude Bellingham',
#  'Aaron Ramsdale',
#  'Callum Wilson',
#  'James Maddison',
#  'Conor Gallagher',
#  'Alireza Beiranvand',
#  'Sadegh Moharrami',
#  'Ehsan Hajsafi (captain)',
#  'Shojae Khalilzadeh',
#  'Milad Mohammadi',
#  'Saeid Ezatolahi',
#  'Alireza Jahanbakhsh',
#  'Morteza Pouraliganji',
#  'Mehdi Taremi',
#  'Karim Ansarifard',
#  'Vahid Amiri',
#  'Payam Niazmand',
#  'Hossein Kanaanizadegan',
#  'Saman Ghoddos',
#  'Rouzbeh Cheshmi',
#  'Mehdi Torabi',
#  'Ali Gholizadeh',
#  'Ali Karimi',
#  'Majid Hosseini',
#  'Sardar Azmoun',
#  'Ahmad Nourollahi',
#  'Amir Abedzadeh',
#  'Ramin Rezaeian',
#  'Hossein Hosseini',
#  'Abolfazl Jalali',
#  'Matt Turner',
#  'Sergiño Dest',
#  'Walker Zimmerman',
#  'Tyler Adams',
#  'Antonee Robinson',
#  'Yunus Musah',
#  'Giovanni Reyna',
#  'Weston McKennie',
#  'Jesús Ferreira',
#  'Christian Pulisic',
#  'Brenden Aaronson',
#  'Ethan Horvath',
#  'Tim Ream',
#  'Luca de la Torre',
#  'Aaron Long',
#  'Jordan Morris',
#  'Cristian Roldan',
#  'Shaq Moore',
#  'Haji Wright',
#  'Cameron Carter-Vickers',
#  'Timothy Weah',
#  'DeAndre Yedlin',
#  'Kellyn Acosta',
#  'Josh Sargent',
#  'Sean Johnson',
#  'Joe Scally',
#  'Wayne Hennessey',
#  'Chris Gunter',
#  'Neco Williams',
#  'Ben Davies',
#  'Chris Mepham',
#  'Joe Rodon',
#  'Joe Allen',
#  'Harry Wilson',
#  'Brennan Johnson',
#  'Aaron Ramsey',
#  'Gareth Bale (captain)',
#  'Danny Ward',
#  'Kieffer Moore',
#  'Connor Roberts',
#  'Ethan Ampadu',
#  'Joe Morrell',
#  'Tom Lockyer',
#  'Jonny Williams',
#  'Mark Harris',
#  'Daniel James',
#  'Adam Davies',
#  'Sorba Thomas',
#  'Dylan Levitt',
#  'Ben Cabango',
#  'Rubin Colwill',
#  'Matthew Smith',
#  'Franco Armani',
#  'Juan Foyth',
#  'Nicolás Tagliafico',
#  'Gonzalo Montiel',
#  'Leandro Paredes',
#  'Germán Pezzella',
#  'Rodrigo De Paul',
#  'Marcos Acuña',
#  'Julián Álvarez',
#  'Lionel Messi (captain)',
#  'Ángel Di María',
#  'Gerónimo Rulli',
#  'Cristian Romero',
#  'Exequiel Palacios',
#  'Ángel Correa',
#  'Thiago Almada',
#  'Papu Gómez',
#  'Guido Rodríguez',
#  'Nicolás Otamendi',
#  'Alexis Mac Allister',
#  'Paulo Dybala',
#  'Lautaro Martínez',
#  'Emiliano Martínez',
#  'Enzo Fernández',
#  'Lisandro Martínez',
#  'Nahuel Molina',
#  'Alfredo Talavera',
#  'Néstor Araujo',
#  'César Montes',
#  'Edson Álvarez',
#  'Johan Vásquez',
#  'Gerardo Arteaga',
#  'Luis Romo',
#  'Carlos Rodríguez',
#  'Raúl Jiménez',
#  'Alexis Vega',
#  'Rogelio Funes Mori',
#  'Rodolfo Cota',
#  'Guillermo Ochoa',
#  'Érick Gutiérrez',
#  'Héctor Moreno',
#  'Héctor Herrera',
#  'Orbelín Pineda',
#  'Andrés Guardado (captain)',
#  'Jorge Sánchez',
#  'Henry Martín',
#  'Uriel Antuna',
#  'Hirving Lozano',
#  'Jesús Gallardo',
#  'Luis Chávez',
#  'Roberto Alvarado',
#  'Kevin Álvarez',
#  'Wojciech Szczęsny',
#  'Matty Cash',
#  'Artur Jędrzejczyk',
#  'Mateusz Wieteska',
#  'Jan Bednarek',
#  'Krystian Bielik',
#  'Arkadiusz Milik',
#  'Damian Szymański',
#  'Robert Lewandowski (captain)',
#  'Grzegorz Krychowiak',
#  'Kamil Grosicki',
#  'Łukasz Skorupski',
#  'Jakub Kamiński',
#  'Jakub Kiwior',
#  'Kamil Glik',
#  'Karol Świderski',
#  'Szymon Żurkowski',
#  'Bartosz Bereszyński',
#  'Sebastian Szymański',
#  'Piotr Zieliński',
#  'Nicola Zalewski',
#  'Kamil Grabara',
#  'Krzysztof Piątek',
#  'Przemysław Frankowski',
#  'Robert Gumny',
#  'Michał Skóraś',
#  'Mohammed Al-Rubaie',
#  'Sultan Al-Ghannam',
#  'Abdullah Madu',
#  'Abdulelah Al-Amri',
#  'Ali Al-Bulaihi',
#  'Mohammed Al-Breik',
#  'Salman Al-Faraj (captain)',
#  'Abdulellah Al-Malki',
#  'Firas Al-Buraikan',
#  'Salem Al-Dawsari',
#  'Saleh Al-Shehri',
#  'Saud Abdulhamid',
#  'Yasser Al-Shahrani',
#  'Abdullah Otayf',
#  'Ali Al-Hassan',
#  'Sami Al-Najei',
#  'Hassan Al-Tambakti',
#  'Nawaf Al-Abed',
#  'Hattan Bahebri',
#  'Abdulrahman Al-Aboud',
#  'Mohammed Al-Owais',
#  'Nawaf Al-Aqidi',
#  'Mohamed Kanno',
#  'Nasser Al-Dawsari',
#  'Haitham Asiri',
#  'Riyadh Sharahili',
#  'Mathew Ryan (captain)',
#  'Miloš Degenek',
#  'Nathaniel Atkinson',
#  'Kye Rowles',
#  'Fran Karačić',
#  'Marco Tilio',
#  'Mathew Leckie',
#  'Bailey Wright',
#  'Jamie Maclaren',
#  'Ajdin Hrustic',
#  'Awer Mabil',
#  'Andrew Redmayne',
#  'Aaron Mooy',
#  'Riley McGree',
#  'Mitchell Duke',
#  'Aziz Behich',
#  'Cameron Devlin',
#  'Danny Vukovic',
#  'Harry Souttar',
#  'Thomas Deng',
#  'Garang Kuol',
#  'Jackson Irvine',
#  'Craig Goodwin',
#  'Joel King',
#  'Jason Cummings',
#  'Keanu Baccus',
#  'Kasper Schmeichel',
#  'Joachim Andersen',
#  'Victor Nelsson',
#  'Simon Kjær (captain)',
#  'Joakim Mæhle',
#  'Andreas Christensen',
#  'Mathias Jensen',
#  'Thomas Delaney',
#  'Martin Braithwaite',
#  'Christian Eriksen',
#  'Andreas Skov Olsen',
#  'Kasper Dolberg',
#  'Rasmus Kristensen',
#  'Mikkel Damsgaard',
#  'Christian Nørgaard',
#  'Oliver Christensen',
#  'Jens Stryger Larsen',
#  'Daniel Wass',
#  'Jonas Wind',
#  'Yussuf Poulsen',
#  'Andreas Cornelius',
#  'Frederik Rønnow',
#  'Pierre-Emile Højbjerg',
#  'Robert Skov',
#  'Jesper Lindstrøm',
#  'Alexander Bah',
#  'Hugo Lloris (captain)',
#  'Benjamin Pavard',
#  'Axel Disasi',
#  'Raphaël Varane',
#  'Jules Koundé',
#  'Matteo Guendouzi',
#  'Antoine Griezmann',
#  'Aurélien Tchouaméni',
#  'Olivier Giroud',
#  'Kylian Mbappé',
#  'Ousmane Dembélé',
#  'Randal Kolo Muani',
#  'Youssouf Fofana',
#  'Adrien Rabiot',
#  'Jordan Veretout',
#  'Steve Mandanda',
#  'William Saliba',
#  'Dayot Upamecano',
#  'Kingsley Coman',
#  'Lucas Hernandez',
#  'Theo Hernandez',
#  'Alphonse Areola',
#  'Ibrahima Konaté',
#  'Eduardo Camavinga',
#  'Marcus Thuram',
#  'Aymen Mathlouthi',
#  'Bilel Ifa',
#  'Montassar Talbi',
#  'Yassine Meriah',
#  'Nader Ghandri',
#  'Dylan Bronn',
#  'Youssef Msakni (captain)',
#  'Hannibal Mejbri',
#  'Issam Jebali',
#  'Wahbi Khazri',
#  'Taha Yassine Khenissi',
#  'Ali Maâloul',
#  'Ferjani Sassi',
#  'Aïssa Laïdouni',
#  'Mohamed Ali Ben Romdhane',
#  'Aymen Dahmen',
#  'Ellyes Skhiri',
#  'Ghailene Chaalali',
#  'Seifeddine Jaziri',
#  'Mohamed Dräger',
#  'Wajdi Kechrida',
#  'Bechir Ben Saïd',
#  'Naïm Sliti',
#  'Ali Abdi',
#  'Anis Ben Slimane',
#  'Mouez Hassen',
#  'Keylor Navas',
#  'Daniel Chacón',
#  'Juan Pablo Vargas',
#  'Keysher Fuller',
#  'Celso Borges',
#  'Óscar Duarte',
#  'Anthony Contreras',
#  'Bryan Oviedo',
#  'Jewison Bennette',
#  'Bryan Ruiz (captain)',
#  'Johan Venegas',
#  'Joel Campbell',
#  'Gerson Torres',
#  'Youstin Salas',
#  'Francisco Calvo',
#  'Carlos Martínez',
#  'Yeltsin Tejeda',
#  'Esteban Alvarado',
#  'Kendall Waston',
#  'Brandon Aguilera',
#  'Douglas López',
#  'Rónald Matarrita',
#  'Patrick Sequeira',
#  'Roan Wilson',
#  'Anthony Hernández',
#  'Álvaro Zamora',
#  'Manuel Neuer (captain)',
#  'Antonio Rüdiger',
#  'David Raum',
#  'Matthias Ginter',
#  'Thilo Kehrer',
#  'Joshua Kimmich',
#  'Kai Havertz',
#  'Leon Goretzka',
#  'Niclas Füllkrug',
#  'Serge Gnabry',
#  'Mario Götze',
#  'Kevin Trapp',
#  'Thomas Müller',
#  'Jamal Musiala',
#  'Niklas Süle',
#  'Lukas Klostermann',
#  'Julian Brandt',
#  'Jonas Hofmann',
#  'Leroy Sané',
#  'Christian Günter',
#  'İlkay Gündoğan',
#  'Marc-André ter Stegen',
#  'Nico Schlotterbeck',
#  'Karim Adeyemi',
#  'Armel Bella-Kotchap',
#  'Youssoufa Moukoko',
#  'Eiji Kawashima',
#  'Miki Yamane',
#  'Shogo Taniguchi',
#  'Ko Itakura',
#  'Yuto Nagatomo',
#  'Wataru Endo',
#  'Gaku Shibasaki',
#  'Ritsu Dōan',
#  'Kaoru Mitoma',
#  'Takumi Minamino',
#  'Takefusa Kubo',
#  'Shūichi Gonda',
#  'Hidemasa Morita',
#  'Junya Ito',
#  'Daichi Kamada',
#  'Takehiro Tomiyasu',
#  'Ao Tanaka',
#  'Takuma Asano',
#  'Hiroki Sakai',
#  'Shuto Machino',
#  'Ayase Ueda',
#  'Maya Yoshida (captain)',
#  'Daniel Schmidt',
#  'Yuki Soma',
#  'Daizen Maeda',
#  'Hiroki Ito',
#  'Robert Sánchez',
#  'César Azpilicueta',
#  'Eric García',
#  'Pau Torres',
#  'Sergio Busquets (captain)',
#  'Marcos Llorente',
#  'Álvaro Morata',
#  'Koke',
#  'Gavi',
#  'Marco Asensio',
#  'Ferran Torres',
#  'Nico Williams',
#  'David Raya',
#  'Alejandro Balde',
#  'Hugo Guillamón',
#  'Rodri',
#  'Yeremy Pino',
#  'Jordi Alba',
#  'Carlos Soler',
#  'Dani Carvajal',
#  'Dani Olmo',
#  'Pablo Sarabia',
#  'Unai Simón',
#  'Aymeric Laporte',
#  'Ansu Fati',
#  'Pedri',
#  'Thibaut Courtois',
#  'Toby Alderweireld',
#  'Arthur Theate',
#  'Wout Faes',
#  'Jan Vertonghen',
#  'Axel Witsel',
#  'Kevin De Bruyne',
#  'Youri Tielemans',
#  'Romelu Lukaku',
#  'Eden Hazard (captain)',
#  'Yannick Carrasco',
#  'Simon Mignolet',
#  'Koen Casteels',
#  'Dries Mertens',
#  'Thomas Meunier',
#  'Thorgan Hazard',
#  'Leandro Trossard',
#  'Amadou Onana',
#  'Leander Dendoncker',
#  'Hans Vanaken',
#  'Timothy Castagne',
#  'Charles De Ketelaere',
#  'Michy Batshuayi',
#  'Loïs Openda',
#  'Jérémy Doku',
#  'Zeno Debast',
#  'Dayne St. Clair',
#  'Alistair Johnston',
#  'Sam Adekugbe',
#  'Kamal Miller',
#  'Steven Vitória',
#  'Samuel Piette',
#  'Stephen Eustáquio',
#  'Liam Fraser',
#  'Lucas Cavallini',
#  'Junior Hoilett',
#  'Tajon Buchanan',
#  'Iké Ugbo',
#  'Atiba Hutchinson (captain)',
#  'Mark-Anthony Kaye',
#  'Ismaël Koné',
#  'James Pantemis',
#  'Cyle Larin',
#  'Milan Borjan',
#  'Alphonso Davies',
#  'Jonathan David',
#  'Jonathan Osorio',
#  'Richie Laryea',
#  'Liam Millar',
#  'David Wotherspoon',
#  'Derek Cornelius',
#  'Joel Waterman',
#  'Dominik Livaković',
#  'Josip Stanišić',
#  'Borna Barišić',
#  'Ivan Perišić',
#  'Martin Erlić',
#  'Dejan Lovren',
#  'Lovro Majer',
#  'Mateo Kovačić',
#  'Andrej Kramarić',
#  'Luka Modrić (captain)',
#  'Marcelo Brozović',
#  'Ivo Grbić',
#  'Nikola Vlašić',
#  'Marko Livaja',
#  'Mario Pašalić',
#  'Bruno Petković',
#  'Ante Budimir',
#  'Mislav Oršić',
#  'Borna Sosa',
#  'Joško Gvardiol',
#  'Domagoj Vida',
#  'Josip Juranović',
#  'Ivica Ivušić',
#  'Josip Šutalo',
#  'Luka Sučić',
#  'Kristijan Jakić',
#  'Yassine Bounou',
#  'Achraf Hakimi',
#  'Noussair Mazraoui',
#  'Sofyan Amrabat',
#  'Nayef Aguerd',
#  'Romain Saïss (captain)',
#  'Hakim Ziyech',
#  'Azzedine Ounahi',
#  'Abderrazak Hamdallah',
#  'Anass Zaroury',
#  'Abdelhamid Sabiri',
#  'Munir Mohamedi',
#  'Ilias Chair',
#  'Zakaria Aboukhlal',
#  'Selim Amallah',
#  'Abde Ezzalzouli',
#  'Sofiane Boufal',
#  'Jawad El Yamiq',
#  'Youssef En-Nesyri',
#  'Achraf Dari',
#  'Walid Cheddira',
#  'Ahmed Reda Tagnaouti',
#  'Bilal El Khannous',
#  'Badr Benoun',
#  'Yahia Attiyat Allah',
#  'Yahya Jabrane',
#  'Alisson',
#  'Danilo',
#  'Thiago Silva (captain)',
#  'Marquinhos',
#  'Casemiro',
#  'Alex Sandro',
#  'Lucas Paquetá',
#  'Fred',
#  'Richarlison',
#  'Neymar',
#  'Raphinha',
#  'Weverton',
#  'Dani Alves',
#  'Éder Militão',
#  'Fabinho',
#  'Alex Telles',
#  'Bruno Guimarães',
#  'Gabriel Jesus',
#  'Antony',
#  'Vinícius Júnior',
#  'Rodrygo',
#  'Éverton Ribeiro',
#  'Ederson',
#  'Bremer',
#  'Pedro',
#  'Gabriel Martinelli',
#  'Simon Ngapandouetnbu',
#  'Jerome Ngom Mbekeli',
#  'Nicolas Nkoulou',
#  'Christopher Wooh',
#  'Gaël Ondoua',
#  'Moumi Ngamaleu',
#  'Georges-Kévin Nkoudou',
#  'André-Frank Zambo Anguissa',
#  'Jean-Pierre Nsame',
#  'Vincent Aboubakar (captain)',
#  'Christian Bassogog',
#  'Karl Toko Ekambi',
#  'Eric Maxim Choupo-Moting',
#  'Samuel Gouet',
#  'Pierre Kunde',
#  'Devis Epassy',
#  'Olivier Mbaizo',
#  'Martin Hongla',
#  'Collins Fai',
#  'Bryan Mbeumo',
#  'Jean-Charles Castelletto',
#  'Olivier Ntcham',
#  'André Onana',
#  'Enzo Ebosse',
#  'Nouhou Tolo',
#  'Souaibou Marou',
#  'Marko Dmitrović',
#  'Strahinja Pavlović',
#  'Strahinja Eraković',
#  'Nikola Milenković',
#  'Miloš Veljković',
#  'Nemanja Maksimović',
#  'Nemanja Radonjić',
#  'Nemanja Gudelj',
#  'Aleksandar Mitrović',
#  'Dušan Tadić (captain)',
#  'Luka Jović',
#  'Predrag Rajković',
#  'Stefan Mitrović',
#  'Andrija Živković',
#  'Srđan Babić',
#  'Saša Lukić',
#  'Filip Kostić',
#  'Dušan Vlahović',
#  'Uroš Račić',
#  'Sergej Milinković-Savić',
#  'Filip Đuričić',
#  'Darko Lazović',
#  'Vanja Milinković-Savić',
#  'Ivan Ilić',
#  'Filip Mladenović',
#  'Marko Grujić',
#  'Yann Sommer',
#  'Edimilson Fernandes',
#  'Silvan Widmer',
#  'Nico Elvedi',
#  'Manuel Akanji',
#  'Denis Zakaria',
#  'Breel Embolo',
#  'Remo Freuler',
#  'Haris Seferovic',
#  'Granit Xhaka (captain)',
#  'Renato Steffen',
#  'Jonas Omlin',
#  'Ricardo Rodriguez',
#  'Michel Aebischer',
#  'Djibril Sow',
#  'Christian Fassnacht',
#  'Ruben Vargas',
#  'Eray Cömert',
#  'Noah Okafor',
#  'Fabian Frei',
#  'Gregor Kobel',
#  'Fabian Schär',
#  'Xherdan Shaqiri',
#  'Philipp Köhn',
#  'Fabian Rieder',
#  'Ardon Jashari',
#  'Lawrence Ati-Zigi',
#  'Tariq Lamptey',
#  'Denis Odoi',
#  'Mohammed Salisu',
#  'Thomas Partey',
#  'Elisha Owusu',
#  'Abdul Fatawu Issahaku',
#  'Daniel-Kofi Kyereh',
#  'Jordan Ayew',
#  'André Ayew (captain)',
#  'Osman Bukari',
#  'Ibrahim Danlad',
#  'Daniel Afriyie',
#  'Gideon Mensah',
#  'Joseph Aidoo',
#  'Abdul Manaf Nurudeen',
#  'Baba Rahman',
#  'Daniel Amartey',
#  'Iñaki Williams',
#  'Mohammed Kudus',
#  'Salis Abdul Samed',
#  'Kamaldeen Sulemana',
#  'Alexander Djiku',
#  'Kamal Sowah',
#  'Antoine Semenyo',
#  'Alidu Seidu',
#  'Rui Patrício',
#  'Diogo Dalot',
#  'Pepe',
#  'Rúben Dias',
#  'Raphaël Guerreiro',
#  'João Palhinha',
#  'Cristiano Ronaldo (captain)',
#  'Bruno Fernandes',
#  'André Silva',
#  'Bernardo Silva',
#  'João Félix',
#  'José Sá',
#  'Danilo Pereira',
#  'William Carvalho',
#  'Rafael Leão',
#  'Vitinha',
#  'João Mário',
#  'Rúben Neves',
#  'Nuno Mendes',
#  'João Cancelo',
#  'Ricardo Horta',
#  'Diogo Costa',
#  'Matheus Nunes',
#  'António Silva',
#  'Otávio',
#  'Gonçalo Ramos',
#  'Kim Seung-gyu',
#  'Yoon Jong-gyu',
#  'Kim Jin-su',
#  'Kim Min-jae',
#  'Jung Woo-young',
#  'Hwang In-beom',
#  'Son Heung-min (captain)',
#  'Paik Seung-ho',
#  'Cho Gue-sung',
#  'Lee Jae-sung',
#  'Hwang Hee-chan',
#  'Song Bum-keun',
#  'Son Jun-ho',
#  'Hong Chul',
#  'Kim Moon-hwan',
#  'Hwang Ui-jo',
#  'Na Sang-ho',
#  'Lee Kang-in',
#  'Kim Young-gwon',
#  'Kwon Kyung-won',
#  'Jo Hyeon-woo',
#  'Kwon Chang-hoon',
#  'Kim Tae-hwan',
#  'Cho Yu-min',
#  'Jeong Woo-yeong',
#  'Song Min-kyu',
#  'Fernando Muslera',
#  'José Giménez',
#  'Diego Godín (captain)',
#  'Ronald Araújo',
#  'Matías Vecino',
#  'Rodrigo Bentancur',
#  'Nicolás de la Cruz',
#  'Facundo Pellistri',
#  'Luis Suárez',
#  'Giorgian de Arrascaeta',
#  'Darwin Núñez',
#  'Sebastián Sosa',
#  'Guillermo Varela',
#  'Lucas Torreira',
#  'Federico Valverde',
#  'Mathías Olivera',
#  'Matías Viña',
#  'Maxi Gómez',
#  'Sebastián Coates',
#  'Facundo Torres',
#  'Edinson Cavani',
#  'Martín Cáceres',
#  'Sergio Rochet',
#  'Agustín Canobbio',
#  'Manuel Ugarte',
#  'José Luis Rodríguez']

# %%
for name in names_list:
    img = find_player(name)

# %%
os.listdir('..')
player_name = 'Alan Franco'
random_number = random.randint(1, 50)
Image(filename= f'../player_imgs/Images/Images/Group A/Ecuador Players/Images_{player_name}/{player_name}{random_number}.jpg')
